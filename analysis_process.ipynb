# %%
# # Extend timeout and set mirror
# options(timeout = 600)
# options(repos = c(CRAN = "https://cloud.r-project.org"))

# # Install BiocManager if needed
# if (!requireNamespace("BiocManager", quietly = TRUE))
#     install.packages("BiocManager")

# # Install packages from CRAN & Bioconductor
# BiocManager::install(c("dada2", "phyloseq", "vegan"))

# # Standard CRAN packages
# install.packages(c(
#   "ggplot2", "pheatmap", "RColorBrewer", "ggpubr", 
#   "ggrepel", "igraph", "tidyverse", "reshape2", "data.table"
# ))

# # Install GitHub packages
# if (!requireNamespace("devtools", quietly = TRUE))
#     install.packages("devtools")

# devtools::install_github("zdk123/SpiecEasi")

# %% [markdown]
# ## Package Installation

# %%
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")
BiocManager::install("ggpubr", force=TRUE)
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.20 (BiocManager 1.30.25), R 4.4.1 (2024-06-14)
#
# Installing package(s) 'ggpubr'
#
# also installing the dependencies ‘nloptr’, ‘pbkrtest’, ‘lme4’, ‘car’, ‘rstatix’
#
#
# Warning message in install.packages(...):
# “installation of package ‘nloptr’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘lme4’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘pbkrtest’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘car’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘rstatix’ had non-zero exit status”
# Warning message in install.packages(...):
# “installation of package ‘ggpubr’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Install GitHub packages
if (!requireNamespace("devtools", quietly = TRUE))
    install.packages("devtools")
# Out:
# also installing the dependencies ‘zip’, ‘diffobj’, ‘gert’, ‘downlit’, ‘brio’, ‘waldo’, ‘usethis’, ‘pkgdown’, ‘profvis’, ‘roxygen2’, ‘testthat’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
devtools::install_github("zdk123/SpiecEasi")
# Out:
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo zdk123/SpiecEasi@HEAD
# VGAM   (NA -> 1.1-13) [CRAN]
# pulsar (NA -> 0.3.11) [CRAN]
# huge   (NA -> 1.3.5 ) [CRAN]
# Installing 3 packages: VGAM, pulsar, huge
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# ── R CMD build ─────────────────────────────────────────────────────────────────
# * checking for file ‘/private/var/folders/ng/bwk7d4ds7wz95l011dbvtc9r0000gn/T/Rtmp9rHoCJ/remotes7482646edc1f/zdk123-SpiecEasi-5f396da/DESCRIPTION’ ... OK
# * preparing ‘SpiecEasi’:
# * checking DESCRIPTION meta-information ... OK
# * cleaning src
# * checking for LF line-endings in source and make files and shell scripts
# * checking for empty or unneeded directories
# Removed empty directory ‘SpiecEasi/inst’
# * looking to see if a ‘data/datalist’ file should be added
# * building ‘SpiecEasi_1.1.3.tar.gz’

# %% [markdown]
# ## Testing all required packages

# %%
# Load required packages
library(dada2)
library(phyloseq)
library(vegan)
library(ggplot2)
library(pheatmap)
library(RColorBrewer)
library(ggrepel)
library(igraph)
library(SpiecEasi)
library(tidyverse)
library(reshape2)
library(data.table)
# Out:
# Loading required package: Rcpp
#
# Loading required package: permute
#
# Loading required package: lattice
#
#
# Attaching package: ‘igraph’
#
#
# The following object is masked from ‘package:vegan’:
#
#     diversity
#
#
# The following object is masked from ‘package:permute’:
#
#     permute
#
#
# The following objects are masked from ‘package:stats’:
#
#     decompose, spectrum
#
#
# The following object is masked from ‘package:base’:
#
#     union
#
#
#
# Attaching package: ‘SpiecEasi’
#
#
# The following object is masked from ‘package:igraph’:
#
#     make_graph
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.4     ✔ tibble    3.2.1
# ✔ purrr     1.0.4     ✔ tidyr     1.3.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ lubridate::%--%()      masks igraph::%--%()
# ✖ dplyr::as_data_frame() masks tibble::as_data_frame(), igraph::as_data_frame()
# ✖ purrr::compose()       masks igraph::compose()
# ✖ tidyr::crossing()      masks igraph::crossing()
# ✖ dplyr::filter()        masks stats::filter()
# ✖ dplyr::lag()           masks stats::lag()
# ✖ purrr::simplify()      masks igraph::simplify()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths
#
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:reshape2’:
#
#     dcast, melt
#
#
# The following objects are masked from ‘package:lubridate’:
#
#     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#     yday, year
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# The following object is masked from ‘package:purrr’:
#
#     transpose

# %% [markdown]
# ## Testing main_analysis functions

# %% [markdown]
# ## 0. Processing FastQ Files

# %%
source('/Users/abhilashdhal/Desktop/DADA2Analysis/src/main_analysis.R')

# %%
path_for_fastq = "/Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq"

# %%
processed_fastq = process_fastq_files(path = path_for_fastq)
# Out:
# 114617160 total bases in 545796 reads from 9 samples will be used for learning the error rates.
# 112137760 total bases in 700861 reads from 10 samples will be used for learning the error rates.
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3739b_F_filt.fastq.gz
#
# Encountered 11760 unique sequences from 64684 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3789b_F_filt.fastq.gz
#
# Encountered 20167 unique sequences from 108050 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3813a_F_filt.fastq.gz
#
# Encountered 8661 unique sequences from 25740 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3819b_F_filt.fastq.gz
#
# Encountered 6261 unique sequences from 18656 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3824b_F_filt.fastq.gz
#
# Encountered 11776 unique sequences from 44995 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3861b_F_filt.fastq.gz
#
# Encountered 9278 unique sequences from 36084 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3863a_F_filt.fastq.gz
#
# Encountered 16152 unique sequences from 76961 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3894b_F_filt.fastq.gz
#
# Encountered 16381 unique sequences from 79555 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3905a_F_filt.fastq.gz
#
# Encountered 18121 unique sequences from 91071 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3909a_F_filt.fastq.gz
#
# Encountered 19649 unique sequences from 155065 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3921a_F_filt.fastq.gz
#
# Encountered 19368 unique sequences from 127053 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3924a_F_filt.fastq.gz
#
# Encountered 18634 unique sequences from 101913 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3946a_F_filt.fastq.gz
#
# Encountered 27475 unique sequences from 151459 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3950a_F_filt.fastq.gz
#
# Encountered 12250 unique sequences from 90704 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3966a_F_filt.fastq.gz
#
# Encountered 22308 unique sequences from 138345 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3977b_F_filt.fastq.gz
#
# Encountered 20113 unique sequences from 102027 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3989b_F_filt.fastq.gz
#
# Encountered 13929 unique sequences from 75915 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4045b_F_filt.fastq.gz
#
# Encountered 12347 unique sequences from 54544 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4073b_F_filt.fastq.gz
#
# Encountered 8453 unique sequences from 34705 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4078a_F_filt.fastq.gz
#
# Encountered 20185 unique sequences from 90526 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4133a_F_filt.fastq.gz
#
# Encountered 23252 unique sequences from 137916 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4146b_F_filt.fastq.gz
#
# Encountered 18576 unique sequences from 85474 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4171b_F_filt.fastq.gz
#
# Encountered 17808 unique sequences from 105984 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4177a_F_filt.fastq.gz
#
# Encountered 16071 unique sequences from 64520 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4206a_F_filt.fastq.gz
#
# Encountered 15235 unique sequences from 106820 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4207a_F_filt.fastq.gz
#
# Encountered 17514 unique sequences from 99078 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4219a_F_filt.fastq.gz
#
# Encountered 15422 unique sequences from 91169 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4234a_F_filt.fastq.gz
#
# Encountered 18350 unique sequences from 82300 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4235b_F_filt.fastq.gz
#
# Encountered 12730 unique sequences from 77921 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4237a_F_filt.fastq.gz
#
# Encountered 9777 unique sequences from 43070 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4240a_F_filt.fastq.gz
#
# Encountered 9019 unique sequences from 38156 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4245b_F_filt.fastq.gz
#
# Encountered 15246 unique sequences from 83964 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4247a_F_filt.fastq.gz
#
# Encountered 7652 unique sequences from 32912 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4252b_F_filt.fastq.gz
#
# Encountered 14600 unique sequences from 59840 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4259b_F_filt.fastq.gz
#
# Encountered 13098 unique sequences from 68116 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4277b_F_filt.fastq.gz
#
# Encountered 10781 unique sequences from 63917 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4299a_F_filt.fastq.gz
#
# Encountered 19817 unique sequences from 70330 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4300a_F_filt.fastq.gz
#
# Encountered 10803 unique sequences from 57734 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4310b_F_filt.fastq.gz
#
# Encountered 13886 unique sequences from 68512 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4347b_F_filt.fastq.gz
#
# Encountered 13053 unique sequences from 109665 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4379b_F_filt.fastq.gz
#
# Encountered 17036 unique sequences from 79438 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4381b_F_filt.fastq.gz
#
# Encountered 9124 unique sequences from 65522 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4397b_F_filt.fastq.gz
#
# Encountered 15501 unique sequences from 46612 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4402b_F_filt.fastq.gz
#
# Encountered 16945 unique sequences from 81420 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4414a_F_filt.fastq.gz
#
# Encountered 19931 unique sequences from 94118 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4415b_F_filt.fastq.gz
#
# Encountered 18670 unique sequences from 103381 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4426b_F_filt.fastq.gz
#
# Encountered 15074 unique sequences from 88060 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4429b_F_filt.fastq.gz
#
# Encountered 18761 unique sequences from 99966 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4436a_F_filt.fastq.gz
#
# Encountered 11158 unique sequences from 62372 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4448b_F_filt.fastq.gz
#
# Encountered 13095 unique sequences from 55108 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4457b_F_filt.fastq.gz
#
# Encountered 19216 unique sequences from 96904 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3739b_R_filt.fastq.gz
#
# Encountered 13293 unique sequences from 64684 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3789b_R_filt.fastq.gz
#
# Encountered 16225 unique sequences from 108050 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3813a_R_filt.fastq.gz
#
# Encountered 6394 unique sequences from 25740 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3819b_R_filt.fastq.gz
#
# Encountered 2466 unique sequences from 18656 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3824b_R_filt.fastq.gz
#
# Encountered 10794 unique sequences from 44995 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3861b_R_filt.fastq.gz
#
# Encountered 8476 unique sequences from 36084 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3863a_R_filt.fastq.gz
#
# Encountered 15293 unique sequences from 76961 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3894b_R_filt.fastq.gz
#
# Encountered 12209 unique sequences from 79555 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3905a_R_filt.fastq.gz
#
# Encountered 22792 unique sequences from 91071 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3909a_R_filt.fastq.gz
#
# Encountered 17881 unique sequences from 155065 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3921a_R_filt.fastq.gz
#
# Encountered 16685 unique sequences from 127053 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3924a_R_filt.fastq.gz
#
# Encountered 9439 unique sequences from 101913 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3946a_R_filt.fastq.gz
#
# Encountered 25203 unique sequences from 151459 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3950a_R_filt.fastq.gz
#
# Encountered 8295 unique sequences from 90704 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3966a_R_filt.fastq.gz
#
# Encountered 17576 unique sequences from 138345 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3977b_R_filt.fastq.gz
#
# Encountered 15256 unique sequences from 102027 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/3989b_R_filt.fastq.gz
#
# Encountered 13415 unique sequences from 75915 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4045b_R_filt.fastq.gz
#
# Encountered 6651 unique sequences from 54544 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4073b_R_filt.fastq.gz
#
# Encountered 7284 unique sequences from 34705 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4078a_R_filt.fastq.gz
#
# Encountered 20648 unique sequences from 90526 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4133a_R_filt.fastq.gz
#
# Encountered 17839 unique sequences from 137916 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4146b_R_filt.fastq.gz
#
# Encountered 12722 unique sequences from 85474 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4171b_R_filt.fastq.gz
#
# Encountered 19171 unique sequences from 105984 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4177a_R_filt.fastq.gz
#
# Encountered 8249 unique sequences from 64520 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4206a_R_filt.fastq.gz
#
# Encountered 10922 unique sequences from 106820 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4207a_R_filt.fastq.gz
#
# Encountered 16534 unique sequences from 99078 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4219a_R_filt.fastq.gz
#
# Encountered 15816 unique sequences from 91169 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4234a_R_filt.fastq.gz
#
# Encountered 14988 unique sequences from 82300 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4235b_R_filt.fastq.gz
#
# Encountered 14827 unique sequences from 77921 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4237a_R_filt.fastq.gz
#
# Encountered 10528 unique sequences from 43070 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4240a_R_filt.fastq.gz
#
# Encountered 9086 unique sequences from 38156 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4245b_R_filt.fastq.gz
#
# Encountered 8608 unique sequences from 83964 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4247a_R_filt.fastq.gz
#
# Encountered 8134 unique sequences from 32912 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4252b_R_filt.fastq.gz
#
# Encountered 13062 unique sequences from 59840 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4259b_R_filt.fastq.gz
#
# Encountered 6885 unique sequences from 68116 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4277b_R_filt.fastq.gz
#
# Encountered 7614 unique sequences from 63917 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4299a_R_filt.fastq.gz
#
# Encountered 12494 unique sequences from 70330 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4300a_R_filt.fastq.gz
#
# Encountered 7449 unique sequences from 57734 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4310b_R_filt.fastq.gz
#
# Encountered 11414 unique sequences from 68512 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4347b_R_filt.fastq.gz
#
# Encountered 12138 unique sequences from 109665 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4379b_R_filt.fastq.gz
#
# Encountered 14406 unique sequences from 79438 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4381b_R_filt.fastq.gz
#
# Encountered 8259 unique sequences from 65522 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4397b_R_filt.fastq.gz
#
# Encountered 8971 unique sequences from 46612 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4402b_R_filt.fastq.gz
#
# Encountered 9481 unique sequences from 81420 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4414a_R_filt.fastq.gz
#
# Encountered 16240 unique sequences from 94118 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4415b_R_filt.fastq.gz
#
# Encountered 15154 unique sequences from 103381 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4426b_R_filt.fastq.gz
#
# Encountered 15480 unique sequences from 88060 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4429b_R_filt.fastq.gz
#
# Encountered 14035 unique sequences from 99966 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4436a_R_filt.fastq.gz
#
# Encountered 9254 unique sequences from 62372 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4448b_R_filt.fastq.gz
#
# Encountered 14443 unique sequences from 55108 total sequences read.
#
# Dereplicating sequence entries in Fastq file: /Users/abhilashdhal/Desktop/DADA2Analysis/data/fastq/filtered/4457b_R_filt.fastq.gz
#
# Encountered 16192 unique sequences from 96904 total sequences read.
# Sample 1 - 64684 reads in 11760 unique sequences.
# Sample 2 - 108050 reads in 20167 unique sequences.
# Sample 3 - 25740 reads in 8661 unique sequences.
# Sample 4 - 18656 reads in 6261 unique sequences.
# Sample 5 - 44995 reads in 11776 unique sequences.
# Sample 6 - 36084 reads in 9278 unique sequences.
# Sample 7 - 76961 reads in 16152 unique sequences.
# Sample 8 - 79555 reads in 16381 unique sequences.
# Sample 9 - 91071 reads in 18121 unique sequences.
# Sample 10 - 155065 reads in 19649 unique sequences.
# Sample 11 - 127053 reads in 19368 unique sequences.
# Sample 12 - 101913 reads in 18634 unique sequences.
# Sample 13 - 151459 reads in 27475 unique sequences.
# Sample 14 - 90704 reads in 12250 unique sequences.
# Sample 15 - 138345 reads in 22308 unique sequences.
# Sample 16 - 102027 reads in 20113 unique sequences.
# Sample 17 - 75915 reads in 13929 unique sequences.
# Sample 18 - 54544 reads in 12347 unique sequences.
# Sample 19 - 34705 reads in 8453 unique sequences.
# Sample 20 - 90526 reads in 20185 unique sequences.
# Sample 21 - 137916 reads in 23252 unique sequences.
# Sample 22 - 85474 reads in 18576 unique sequences.
# Sample 23 - 105984 reads in 17808 unique sequences.
# Sample 24 - 64520 reads in 16071 unique sequences.
# Sample 25 - 106820 reads in 15235 unique sequences.
# Sample 26 - 99078 reads in 17514 unique sequences.
# Sample 27 - 91169 reads in 15422 unique sequences.
# Sample 28 - 82300 reads in 18350 unique sequences.
# Sample 29 - 77921 reads in 12730 unique sequences.
# Sample 30 - 43070 reads in 9777 unique sequences.
# Sample 31 - 38156 reads in 9019 unique sequences.
# Sample 32 - 83964 reads in 15246 unique sequences.
# Sample 33 - 32912 reads in 7652 unique sequences.
# Sample 34 - 59840 reads in 14600 unique sequences.
# Sample 35 - 68116 reads in 13098 unique sequences.
# Sample 36 - 63917 reads in 10781 unique sequences.
# Sample 37 - 70330 reads in 19817 unique sequences.
# Sample 38 - 57734 reads in 10803 unique sequences.
# Sample 39 - 68512 reads in 13886 unique sequences.
# Sample 40 - 109665 reads in 13053 unique sequences.
# Sample 41 - 79438 reads in 17036 unique sequences.
# Sample 42 - 65522 reads in 9124 unique sequences.
# Sample 43 - 46612 reads in 15501 unique sequences.
# Sample 44 - 81420 reads in 16945 unique sequences.
# Sample 45 - 94118 reads in 19931 unique sequences.
# Sample 46 - 103381 reads in 18670 unique sequences.
# Sample 47 - 88060 reads in 15074 unique sequences.
# Sample 48 - 99966 reads in 18761 unique sequences.
# Sample 49 - 62372 reads in 11158 unique sequences.
# Sample 50 - 55108 reads in 13095 unique sequences.
# Sample 51 - 96904 reads in 19216 unique sequences.
# Sample 1 - 64684 reads in 13293 unique sequences.
# Sample 2 - 108050 reads in 16225 unique sequences.
# Sample 3 - 25740 reads in 6394 unique sequences.
# Sample 4 - 18656 reads in 2466 unique sequences.
# Sample 5 - 44995 reads in 10794 unique sequences.
# Sample 6 - 36084 reads in 8476 unique sequences.
# Sample 7 - 76961 reads in 15293 unique sequences.
# Sample 8 - 79555 reads in 12209 unique sequences.
# Sample 9 - 91071 reads in 22792 unique sequences.
# Sample 10 - 155065 reads in 17881 unique sequences.
# Sample 11 - 127053 reads in 16685 unique sequences.
# Sample 12 - 101913 reads in 9439 unique sequences.
# Sample 13 - 151459 reads in 25203 unique sequences.
# Sample 14 - 90704 reads in 8295 unique sequences.
# Sample 15 - 138345 reads in 17576 unique sequences.
# Sample 16 - 102027 reads in 15256 unique sequences.
# Sample 17 - 75915 reads in 13415 unique sequences.
# Sample 18 - 54544 reads in 6651 unique sequences.
# Sample 19 - 34705 reads in 7284 unique sequences.
# Sample 20 - 90526 reads in 20648 unique sequences.
# Sample 21 - 137916 reads in 17839 unique sequences.
# Sample 22 - 85474 reads in 12722 unique sequences.
# Sample 23 - 105984 reads in 19171 unique sequences.
# Sample 24 - 64520 reads in 8249 unique sequences.
# Sample 25 - 106820 reads in 10922 unique sequences.
# Sample 26 - 99078 reads in 16534 unique sequences.
# Sample 27 - 91169 reads in 15816 unique sequences.
# Sample 28 - 82300 reads in 14988 unique sequences.
# Sample 29 - 77921 reads in 14827 unique sequences.
# Sample 30 - 43070 reads in 10528 unique sequences.
# Sample 31 - 38156 reads in 9086 unique sequences.
# Sample 32 - 83964 reads in 8608 unique sequences.
# Sample 33 - 32912 reads in 8134 unique sequences.
# Sample 34 - 59840 reads in 13062 unique sequences.
# Sample 35 - 68116 reads in 6885 unique sequences.
# Sample 36 - 63917 reads in 7614 unique sequences.
# Sample 37 - 70330 reads in 12494 unique sequences.
# Sample 38 - 57734 reads in 7449 unique sequences.
# Sample 39 - 68512 reads in 11414 unique sequences.
# Sample 40 - 109665 reads in 12138 unique sequences.
# Sample 41 - 79438 reads in 14406 unique sequences.
# Sample 42 - 65522 reads in 8259 unique sequences.
# Sample 43 - 46612 reads in 8971 unique sequences.
# Sample 44 - 81420 reads in 9481 unique sequences.
# Sample 45 - 94118 reads in 16240 unique sequences.
# Sample 46 - 103381 reads in 15154 unique sequences.
# Sample 47 - 88060 reads in 15480 unique sequences.
# Sample 48 - 99966 reads in 14035 unique sequences.
# Sample 49 - 62372 reads in 9254 unique sequences.
# Sample 50 - 55108 reads in 14443 unique sequences.
# Sample 51 - 96904 reads in 16192 unique sequences.
# 5 paired-reads (in 5 unique pairings) successfully merged out of 64616 (in 1801 pairings) input.
#
# 11 paired-reads (in 7 unique pairings) successfully merged out of 107518 (in 4659 pairings) input.
#
# 1282 paired-reads (in 156 unique pairings) successfully merged out of 24872 (in 3162 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 18576 (in 772 pairings) input.
#
# 945 paired-reads (in 34 unique pairings) successfully merged out of 43634 (in 4253 pairings) input.
#
# 2376 paired-reads (in 302 unique pairings) successfully merged out of 34980 (in 3172 pairings) input.
#
# 82 paired-reads (in 19 unique pairings) successfully merged out of 76730 (in 5091 pairings) input.
#
# 29 paired-reads (in 4 unique pairings) successfully merged out of 79369 (in 2379 pairings) input.
#
# 2462 paired-reads (in 317 unique pairings) successfully merged out of 90723 (in 5840 pairings) input.
#
# 1664 paired-reads (in 57 unique pairings) successfully merged out of 153650 (in 4401 pairings) input.
#
# 47 paired-reads (in 13 unique pairings) successfully merged out of 126691 (in 2481 pairings) input.
#
# 37 paired-reads (in 14 unique pairings) successfully merged out of 101659 (in 2135 pairings) input.
#
# 7 paired-reads (in 6 unique pairings) successfully merged out of 150143 (in 10260 pairings) input.
#
# 5 paired-reads (in 5 unique pairings) successfully merged out of 90626 (in 1231 pairings) input.
#
# 7 paired-reads (in 1 unique pairings) successfully merged out of 137694 (in 6184 pairings) input.
#
# 88 paired-reads (in 7 unique pairings) successfully merged out of 101646 (in 3383 pairings) input.
#
# 30 paired-reads (in 1 unique pairings) successfully merged out of 75706 (in 1929 pairings) input.
#
# 43 paired-reads (in 1 unique pairings) successfully merged out of 54314 (in 903 pairings) input.
#
# 259 paired-reads (in 10 unique pairings) successfully merged out of 34388 (in 3610 pairings) input.
#
# 296 paired-reads (in 10 unique pairings) successfully merged out of 89314 (in 8154 pairings) input.
#
# 6 paired-reads (in 4 unique pairings) successfully merged out of 137398 (in 6427 pairings) input.
#
# 4 paired-reads (in 3 unique pairings) successfully merged out of 85088 (in 5741 pairings) input.
#
# 79 paired-reads (in 24 unique pairings) successfully merged out of 105528 (in 2566 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 64170 (in 3213 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 106689 (in 1670 pairings) input.
#
# 6 paired-reads (in 3 unique pairings) successfully merged out of 99026 (in 2839 pairings) input.
#
# 175 paired-reads (in 22 unique pairings) successfully merged out of 90628 (in 3194 pairings) input.
#
# 2 paired-reads (in 1 unique pairings) successfully merged out of 81646 (in 5196 pairings) input.
#
# 4 paired-reads (in 3 unique pairings) successfully merged out of 77850 (in 1298 pairings) input.
#
# 192 paired-reads (in 3 unique pairings) successfully merged out of 42640 (in 5038 pairings) input.
#
# 230 paired-reads (in 3 unique pairings) successfully merged out of 37416 (in 4729 pairings) input.
#
# 23 paired-reads (in 3 unique pairings) successfully merged out of 83854 (in 370 pairings) input.
#
# 187 paired-reads (in 4 unique pairings) successfully merged out of 32125 (in 4703 pairings) input.
#
# 2053 paired-reads (in 216 unique pairings) successfully merged out of 58302 (in 6606 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 67776 (in 691 pairings) input.
#
# 2 paired-reads (in 1 unique pairings) successfully merged out of 63871 (in 692 pairings) input.
#
# 6 paired-reads (in 4 unique pairings) successfully merged out of 69272 (in 7017 pairings) input.
#
# 33 paired-reads (in 13 unique pairings) successfully merged out of 57541 (in 1282 pairings) input.
#
# 48 paired-reads (in 6 unique pairings) successfully merged out of 68244 (in 3066 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 109644 (in 340 pairings) input.
#
# 11 paired-reads (in 7 unique pairings) successfully merged out of 78690 (in 6887 pairings) input.
#
# 6 paired-reads (in 5 unique pairings) successfully merged out of 65324 (in 570 pairings) input.
#
# 120 paired-reads (in 4 unique pairings) successfully merged out of 45566 (in 4998 pairings) input.
#
# 0 paired-reads (in 0 unique pairings) successfully merged out of 81182 (in 3119 pairings) input.
#
# 121 paired-reads (in 8 unique pairings) successfully merged out of 93366 (in 7143 pairings) input.
#
# 48 paired-reads (in 10 unique pairings) successfully merged out of 102919 (in 3074 pairings) input.
#
# 11 paired-reads (in 7 unique pairings) successfully merged out of 87857 (in 2255 pairings) input.
#
# 14 paired-reads (in 7 unique pairings) successfully merged out of 99362 (in 2847 pairings) input.
#
# 10 paired-reads (in 5 unique pairings) successfully merged out of 62168 (in 1649 pairings) input.
#
# 1639 paired-reads (in 166 unique pairings) successfully merged out of 53569 (in 5356 pairings) input.
#
# 127 paired-reads (in 8 unique pairings) successfully merged out of 96276 (in 5441 pairings) input.
#
# Identified 711 bimeras out of 1072 input sequences.

# %% [markdown]
# ## Analysis

# %%
# Function to perform taxonomic assignment
assign_taxonomy <- function(seqtab) {
    # Assign taxonomy using Silva database
    taxa <- assignTaxonomy(seqtab, 
                          "/Users/abhilashdhal/Desktop/DADA2Analysis/data/tax/silva_nr_v132_train_set.fa.gz",
                          multithread = TRUE)
    
    # Add species level assignment
    taxa <- addSpecies(taxa, "/Users/abhilashdhal/Desktop/DADA2Analysis/data/tax/silva_species_assignment_v132.fa.gz")
    
    # Save taxonomic assignments
    write.csv(taxa, "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/taxonomic_assignments.csv")
    
    return(taxa)
}

# Function to filter out contaminants and unwanted taxa
filter_contaminants <- function(taxa) {
    # Convert taxa matrix to data frame
    tax_table <- as.data.frame(taxa)
    
    # Print initial statistics
    cat("Initial status:\n")
    cat("Total taxa:", nrow(tax_table), "\n")
    
    # Print kingdom-level distribution
    kingdom_counts <- table(tax_table$Kingdom)
    cat("\nKingdom distribution:\n")
    print(kingdom_counts)
    
    # Keep only bacteria (remove eukaryotes, chloroplasts, mitochondria)
    keep_taxa <- rownames(tax_table)[
        (!is.na(tax_table$Kingdom) & tax_table$Kingdom == "Bacteria") &
        !grepl("Chloroplast|Mitochondria", tax_table$Family, ignore.case = TRUE) &
        !grepl("Chloroplast|Mitochondria", tax_table$Order, ignore.case = TRUE)
    ]
    
    # Check if we have any taxa left
    if(length(keep_taxa) == 0) {
        stop("No bacterial taxa found after filtering!")
    }
    
    # Print number of taxa retained
    cat("\nTaxa after filtering:", length(keep_taxa), "\n")
    
    # Print family-level distribution for retained taxa
    family_counts <- table(tax_table[keep_taxa, "Family"])
    cat("\nFamily distribution of retained taxa:\n")
    print(family_counts)
    
    # Create filtered taxonomy table
    taxa_filtered <- taxa[keep_taxa, ]
    
    # Save filtering statistics
    filter_stats <- data.frame(
        Metric = c("Original taxa", "Filtered taxa",
                  "Number of families"),
        Value = c(nrow(taxa), nrow(taxa_filtered),
                 length(unique(na.omit(tax_table[keep_taxa, "Family"]))))
    )
    write.csv(filter_stats, "results/tables/taxonomy_filtering_statistics.csv")
    
    return(taxa_filtered)
}

# Function to create metadata from sample names
create_metadata <- function(sample_names) {
    metadata <- data.frame(
        Sample = sample_names,
        Group = ifelse(grepl("a", sample_names), "Group A", "Group B"),
        row.names = sample_names
    )
    write.csv(metadata, "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/sample_metadata.csv")
    return(metadata)
}


# Function to create phyloseq object
create_phyloseq <- function(seqtab, taxa, sample_names) {
    # Create metadata
    metadata <- create_metadata(sample_names)
    
    # Filter taxonomy to keep only bacterial families
    taxa_filtered <- filter_contaminants(taxa)
    
    # Subset sequence table to keep only filtered taxa
    seqtab_filtered <- seqtab[, colnames(seqtab) %in% rownames(taxa_filtered)]
    
    # Create phyloseq object
    ps <- phyloseq(otu_table(seqtab_filtered, taxa_are_rows = FALSE),
                   tax_table(taxa_filtered),
                   sample_data(metadata))
    
    # Remove any samples with zero reads after filtering
    ps <- prune_samples(sample_sums(ps) > 0, ps)
    
    # Print final statistics
    cat("\nFinal phyloseq object status:\n")
    cat("Samples:", nsamples(ps), "\n")
    cat("Taxa:", ntaxa(ps), "\n")
    cat("Total reads:", sum(sample_sums(ps)), "\n")
    
    return(ps)
}

# Function to calculate alpha diversity
calculate_alpha_diversity <- function(ps) {
    # Calculate various alpha diversity metrics
    alpha_div <- estimate_richness(ps, measures = c("Shannon", "Simpson", "Chao1"))
    
    # Add sample information
    alpha_div$Sample <- rownames(alpha_div)
    alpha_div$Group <- sample_data(ps)$Group
    
    # Perform statistical tests
    shannon_test <- wilcox.test(Shannon ~ Group, data = alpha_div)
    simpson_test <- wilcox.test(Simpson ~ Group, data = alpha_div)
    chao1_test <- wilcox.test(Chao1 ~ Group, data = alpha_div)
    
    # Save test results
    test_results <- data.frame(
        Metric = c("Shannon", "Simpson", "Chao1"),
        p_value = c(shannon_test$p.value, simpson_test$p.value, chao1_test$p.value)
    )
    write.csv(test_results, "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/alpha_diversity_tests.csv")
    
    return(alpha_div)
}

# %% [markdown]
# ## Alfa diversity calculation

# %%
# Get sample names from sequence table
sample_names <- rownames(processed_fastq)

# Assign taxonomy
taxa <- assign_taxonomy(processed_fastq)

# Create phyloseq object
ps <- create_phyloseq(processed_fastq, taxa, sample_names)

# Calculate alpha diversity
alpha_div <- calculate_alpha_diversity(ps)

# Save alpha diversity results
write.csv(alpha_div, "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/alpha_diversity.csv")
# Out:
# Initial status:
# Total taxa: 361
#
# Kingdom distribution:
#
#  Bacteria Eukaryota
#       160       130
#
# Taxa after filtering: 159
#
# Family distribution of retained taxa:
#
#   Burkholderiaceae  Carnobacteriaceae Corynebacteriaceae Enterobacteriaceae
#                  1                  7                 20                  7
#   Fusobacteriaceae      Moraxellaceae      Neisseriaceae    Pasteurellaceae
#                  2                 34                  3                  3
#     Prevotellaceae  Rubrobacteriaceae  Staphylococcaceae   Streptococcaceae
#                  5                  1                 21                 37
#
# Final phyloseq object status:
# Samples: 36
# Taxa: 159
# Total reads: 748
# Warning message in wilcox.test.default(x = DATA[[1L]], y = DATA[[2L]], ...):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(x = DATA[[1L]], y = DATA[[2L]], ...):
# “cannot compute exact p-value with ties”
# Warning message in wilcox.test.default(x = DATA[[1L]], y = DATA[[2L]], ...):
# “cannot compute exact p-value with ties”

# %% [markdown]
# ## Beta Diversity Analysis

# %%
# Function to calculate beta diversity
# Function to calculate beta diversity
# Function to calculate beta diversity
calculate_beta_diversity <- function(ps) {
    # Remove samples with zero reads
    ps <- prune_samples(sample_sums(ps) > 0, ps)
    
    # Remove taxa with zero reads
    ps <- prune_taxa(taxa_sums(ps) > 0, ps)
    
    # Convert to relative abundance to handle different sequencing depths
    ps_rel <- transform_sample_counts(ps, function(x) x/sum(x))
    
    # Replace any remaining zeros with a small value to avoid infinite distances
    otu_table(ps_rel)[otu_table(ps_rel) == 0] <- 1e-10
    
    # Calculate distance matrix
    dist_matrix <- distance(ps_rel, method = "bray")
    
    # Check for any infinite or NA values
    if(any(is.infinite(dist_matrix)) || any(is.na(dist_matrix))) {
        warning("Infinite or NA values detected in distance matrix. Using alternative method.")
        # Use alternative method: Hellinger transformation
        ps_hell <- transform_sample_counts(ps, function(x) sqrt(x/sum(x)))
        dist_matrix <- distance(ps_hell, method = "bray")
    }
    
    # Perform PCoA
    pcoa <- ordinate(ps_rel, method = "PCoA", distance = "bray")
    
    # Prepare metadata for PERMANOVA
    metadata <- data.frame(Group = sample_data(ps)$Group)
    rownames(metadata) <- sample_names(ps)
    
    # Perform PERMANOVA
    permanova <- adonis2(dist_matrix ~ Group, data = metadata)
    write.csv(permanova, "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/permanova_results.csv")
    
    # Save distance matrix
    write.csv(as.matrix(dist_matrix), "/Users/abhilashdhal/Desktop/DADA2Analysis/results/tables/beta_diversity.csv")
    
    return(list(dist_matrix = dist_matrix, pcoa = pcoa))
}

# Function to create composition heatmaps
create_composition_heatmap <- function(ps, level) {
    # Aggregate to specified taxonomic level
    ps_agg <- tax_glom(ps, taxrank = level)
    
    # Convert to relative abundance
    ps_agg_rel <- transform_sample_counts(ps_agg, function(x) x/sum(x))
    
    # Extract abundance matrix
    abund_matrix <- as.matrix(otu_table(ps_agg_rel))
    
    # Get top taxa
    top_taxa <- names(sort(rowSums(abund_matrix), decreasing = TRUE)[1:20])
    abund_matrix <- abund_matrix[top_taxa, ]
    
    # Create heatmap
    pheatmap(abund_matrix,
             scale = "row",
             clustering_distance_rows = "correlation",
             clustering_distance_cols = "correlation",
             show_rownames = TRUE,
             show_colnames = TRUE,
             filename = paste0("/Users/abhilashdhal/Desktop/DADA2Analysis/results/plots/heatmap_", level, ".pdf"))
}

# Function to plot beta diversity results
plot_beta_diversity <- function(beta_div, ps) {
    # Extract PCoA coordinates from the vectors component
    pcoa_scores <- beta_div$pcoa$vectors
    
    # Get sample names from PCoA scores
    pcoa_samples <- rownames(pcoa_scores)
    
    # Subset phyloseq object to match PCoA samples
    ps_subset <- prune_samples(pcoa_samples, ps)
    
    # Create data frame for plotting
    plot_data <- data.frame(
        PC1 = pcoa_scores[, 1],
        PC2 = pcoa_scores[, 2],
        Group = sample_data(ps_subset)$Group,
        Sample = pcoa_samples
    )
    
    # Calculate variance explained
    var_explained <- round(beta_div$pcoa$values$Relative_eig * 100, 1)
    
    # Create PCoA plot
    p <- ggplot(plot_data, aes(x = PC1, y = PC2, color = Group)) +
        geom_point(size = 3) +
        stat_ellipse(level = 0.95, type = "t") +  # Use t-distribution for ellipses
        geom_text_repel(aes(label = Sample), 
                       size = 3, 
                       max.overlaps = 50,  # Increase max overlaps
                       min.segment.length = 0.1,  # Reduce minimum segment length
                       box.padding = 0.5) +  # Add padding around labels
        scale_color_brewer(palette = "Set1") +
        labs(
            x = paste0("PC1 (", var_explained[1], "%)"),
            y = paste0("PC2 (", var_explained[2], "%)"),
            title = "Principal Coordinates Analysis (PCoA)",
            subtitle = "Based on Bray-Curtis dissimilarity"
        ) +
        theme_minimal() +
        theme(
            plot.title = element_text(hjust = 0.5),
            plot.subtitle = element_text(hjust = 0.5),
            legend.position = "right"
        )
    
    # Save the plot
    ggsave("/Users/abhilashdhal/Desktop/DADA2Analysis/results/plots/beta_diversity_pcoa.pdf", p, width = 12, height = 10)  # Increase plot size
    
    # Create distance boxplot
    dist_matrix <- as.matrix(beta_div$dist_matrix)
    
    # Use reshape2::melt explicitly to avoid conflicts
    dist_data <- reshape2::melt(dist_matrix)
    colnames(dist_data) <- c("Sample1", "Sample2", "Distance")
    
    # Remove self-comparisons and duplicates
    dist_data <- dist_data[dist_data$Sample1 < dist_data$Sample2, ]
    
    # Add group information
    dist_data$Group1 <- sample_data(ps_subset)[dist_data$Sample1, "Group"]
    dist_data$Group2 <- sample_data(ps_subset)[dist_data$Sample2, "Group"]
    dist_data$Comparison <- ifelse(dist_data$Group1 == dist_data$Group2, 
                                 "Within Group", "Between Groups")
    
    # Create boxplot
    p_box <- ggplot(dist_data, aes(x = Comparison, y = Distance, fill = Comparison)) +
        geom_boxplot() +
        scale_fill_brewer(palette = "Set2") +
        labs(
            title = "Beta Diversity Distances",
            subtitle = "Bray-Curtis dissimilarity",
            x = "Comparison Type",
            y = "Distance"
        ) +
        theme_minimal() +
        theme(
            plot.title = element_text(hjust = 0.5),
            plot.subtitle = element_text(hjust = 0.5),
            legend.position = "none"
        )
    
    # Save the boxplot
    ggsave("/Users/abhilashdhal/Desktop/DADA2Analysis/results/plots/beta_diversity_boxplot.pdf", p_box, width = 8, height = 6)
    
    return(list(pcoa_plot = p, boxplot = p_box))
}

# %%
ps
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 159 taxa and 36 samples ]
# sample_data() Sample Data:       [ 36 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 159 taxa by 7 taxonomic ranks ]

# %% [markdown]
# ## Beta Diversity Analysis

# %%
# Calculate beta diversity
beta_div <- calculate_beta_diversity(ps)

# Save beta diversity results
write.csv(as.matrix(beta_div$dist_matrix), "results/tables/beta_diversity.csv")

# %%
plot_beta_diversity(beta_div = beta_div, ps=ps)
# Out:
# Warning message in MASS::cov.trob(data[, vars]):
# “Probable convergence failure”
# Warning message in MASS::cov.trob(data[, vars]):
# “Probable convergence failure”
# Warning message in Ops.factor(dist_data$Sample1, dist_data$Sample2):
# “‘<’ not meaningful for factors”
# Warning message:
# “Removed 1296 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# Warning message in MASS::cov.trob(data[, vars]):
# “Probable convergence failure”
# Warning message in MASS::cov.trob(data[, vars]):
# “Probable convergence failure”
# Warning message:
# “Removed 1296 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# $pcoa_plot
#
# $boxplot
# plot without title
# plot without title

# %% [markdown]
# ## Composition Heatmap

# %%
# # Create composition heatmaps
# for (level in c("Phylum", "Genus", "Species")) {
#     create_composition_heatmap(ps, level)
# }

# %% [markdown]
# ## Network Analysis

# %%
# Function to perform network analysis
perform_network_analysis <- function(ps) {
    # Convert to relative abundance
    ps_rel <- transform_sample_counts(ps, function(x) x/sum(x))
    
    # Extract abundance matrix
    abund_matrix <- as.matrix(otu_table(ps_rel))
    
    # Remove taxa with zero variance
    var_taxa <- apply(abund_matrix, 1, var)
    abund_matrix <- abund_matrix[var_taxa > 0, ]
    
    # Check if we have any taxa left
    if (nrow(abund_matrix) == 0) {
        warning("No taxa with non-zero variance found. Skipping network analysis.")
        return(list(network = NULL, clusters = NULL))
    }
    
    # Check if we have enough taxa for correlation
    if (nrow(abund_matrix) < 2) {
        warning("Insufficient number of taxa for network analysis. Need at least 2 taxa.")
        return(list(network = NULL, clusters = NULL))
    }
    
    # Calculate correlation matrix with handling of NaN values
    cor_matrix <- cor(t(abund_matrix), method = "spearman", use = "pairwise.complete.obs")
    
    # Replace any remaining NaN values with 0
    cor_matrix[is.na(cor_matrix)] <- 0
    
    # Create network with absolute correlations
    net <- graph.adjacency(abs(cor_matrix), mode = "undirected", weighted = TRUE, diag = FALSE)
    
    # Remove edges with zero weight
    net <- delete.edges(net, which(E(net)$weight == 0))
    
    # Check if we have any edges left
    if (ecount(net) == 0) {
        warning("No significant correlations found. Network is empty.")
        return(list(network = NULL, clusters = NULL))
    }
    
    # Identify clusters
    clusters <- cluster_fast_greedy(net)
    
    # Save network metrics
    network_metrics <- data.frame(
        Nodes = vcount(net),
        Edges = ecount(net),
        Density = graph.density(net),
        Modularity = modularity(clusters)
    )
    write.csv(network_metrics, "results/tables/network_metrics.csv")
    
    return(list(network = net, clusters = clusters))
}

# %%
# Perform network analysis
network_results <- perform_network_analysis(ps)

# Save network results
saveRDS(network_results, "results/tables/network_analysis.rds")
